# %% [markdown]
# <a href="https://colab.research.google.com/github/ivansanchezflores921-web/ivan-sanchez-vanessa-cardenas-py-2PRACTICAS../blob/main/regla_de_el_trapecio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#regla del trapecio

import numpy as np #Importa la libreria numpy para calculos matematicos

def f(x): #Define la funcion a integrar
 return x**2 #Retorna el valor de la funcion x^2

a = 0 #Limite inferior de integracion
b = 2 #Limite superior de integracion
n = 100 #Numero de subintervalos

h = (b-a)/n #Calcula el tamaño del paso

x = np.linspace(a,b,n+1) #Genera los puntos de discretizacion del intervalo

y = f(x) #Evalua la funcion en todos los puntos

integral = (h/2)*(y[0]+2*np.sum(y[1:n])+y[n]) #aplica la formula de el trapecio compuesto

print("Integral aproximada (Trapecio):", integral) #Muestra los resultados numericos
# Out:
# Integral aproximada (Trapecio): 2.6668000000000003

# %%
#regla de el simsomn
a = 0 # limite inferior
b = 2 # limite superior
n = 100 # numero de sub intervaos ( debe ser par)


h = (b-a)/n # calcula el tamaño de el paso

x = np.linspace(a,b,n+1) # genra los nodos del intervalo

f = f(x) # evalua la funcion
suma = y[0] +y [n] # inicializa la suma de extremos
for i in range ( 1,n) : # itera sobre los puntos inferiores
    if i %2 == 0: #verifica si el indice es par
        suma +=2*y[i] #aplica cooeficiente 2
    else:
        suma +=4*y[i] # aplica el coeficiente 4

integral = (h/3)*suma # aplica la formula de simson

print("integral aproximada (simson):",integral) # muestra el resultado
# Out:
# integral aproximada (simson): 2.6666666666666674

# %%
  # funcion de tipo disttributivo

import numpy as np # importa numpy
def f(x): # define la funcion tipo glassoma
    return np.exp(-x**2) # calcula e^{-x^2}

a = 0 # limite inferior
b = 2 # limite superior
n = 100 # numero de sub intervaos

h = (b-a)/n # calcula el tamaño de el paso
x = np.linspace(a,b,n+1) # genra los nodos del intervalo
y = f(x) # evalua la funcion

integral = (h/2)*(y[0]+ 2*np.sum(y[1:n])+ y[n]) # aplica

print (" area bajo la curva :" ,integral) #resultado
# Out:
#  area bajo la curva : 0.8820789488400428

# %%
#integral doble basica
import numpy as np # importa la biblioteca de numpy

def f(x,y): # define la fncion de las dos variables
    return x+y # retornal la suma de variables

a, b = 0,1 # define los limites en el eje en x
c ,d = 0,1 # definee los limites en el eje y

n = 50 # numero de diviciones en x
m = 50 # numero de diviciones en y

dx = (b-a)/n # calcula el tamaño en el paso en x
dy = (d-c)/m # calcula el tamaño en el paso en y

integral = 0 # inicializa el acumulador de la integral

for i in range (n): # itera sobrelas particulas en x
    for j in range (m):# itera sobre las participaciones en y

        x = a + i*dx # calcula la coordenada x en la malla
        y = c + j*dy # calcula la cordenada y en la malla

        integral += f(x,y)*dx*dy # suma el aire elemental

print (" integral doble aproximada :",integral ) # muestra el resultado
# Out:
#  integral doble aproximada : 0.9800000000000004

# %%
# metodo de el trapecio en 2d
import numpy as np # i porta numpy

def f(x,y): # define funcion dibimensional
    return x**2 + y**2 # funcion cuadratica

a, b = 0,1 # limites en el eje en x
c ,d = 0,1 # limites en el eje y

n = 50 # numero de puntos en x
m = 50 # numero de puntos en y

x = np.linspace (a,b,n) # genera puntos en x
y = np.linspace (c,d,m) # genera puntos en y

dx = (b-a)/(n-1) # paso en x
dy = (d-c)/ (m-1) #paso en y

integral = 0 # inicia el acumulador

for i in range (n): # itera en x
    for j in range (m): # itera en y

        peso = 1 # inicializa el peso

        if i==0 or i ==n-1: # verifica si esta en el borde en x
            peso *= 0.5 # ajusta el borde
        if j==0 or j ==m-1: # verifica si esta en el borde en y
            peso *= 0.5 # ajusta el borde

        integral += peso *f(x[i],y[j]) # acumla el valor ponderado

integral *= dx*dy # mulyiplica por cada area de el elemento

print("integral(trapecio2d):",integral )# muuestra resultado
# Out:
# integral(trapecio2d): 0.6668054977092885

# %%
import numpy as np #imporata Numpy
def f(x,y): #define fincion tipo gaussiana
    return np.exp(-(x**2 + y**2)) # calcula e^{-(X^2+y^)}

a , b = -1,1 # limites en el eje x
c ,d = -1,1 # limites en el eje y

n = 100 # numero de puntos en x
m = 100 # numero de puntos en y

dx = (b-a)/n # calcula el paso en x
dy = (d-c)/m # calcula el paso en y

integral = 0 # inicia el acumulador

for i in range (n): #itera en x
     for j in range (m): # itera en y

      x = a + i*dx # calcula el punto en x
      y = c + j*dy # calcula el punto en y

      integral += f(x,y )*dx*dy
print (" integral doble aproximada :",integral ) # muestra el resultado
# Out:
#  integral doble aproximada : 2.2308386131926694
